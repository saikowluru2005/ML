# %% [markdown]
# <a href="https://colab.research.google.com/github/saikowluru2005/ml/blob/main/Iphone.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv("/content/iphone.csv")

# %%
df
# Out:
#     Iphone  Price
# 0        1    599
# 1        2    649
# 2        3    649
# 3        4    749
# 4        5    769
# 5        6    789
# 6        7    799
# 7        8    800
# 8        9    949
# 9       10   1000
# 10      11   1100
# 11      12   1599

# %%
plt.scatter(df['Iphone'],df['Price'])

# %%
LR=LinearRegression()

# %%
LR.fit(df[['Iphone']],df[['Price']])
# Out:
# LinearRegression()

# %%
LR.predict([[30]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[2400.7995338]])
